# %%
import pandas as pd

# %%
df = pd.read_json("../data/의류수거함 위치 현황.json")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연번      1268 non-null   int64
#  1   설치장소    1268 non-null   object
#  2   행정동     1268 non-null   object
#  3   전화번호    1268 non-null   object
#  4   관리부서    1268 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 49.7+ KB

# %%
df.groupby('설치장소').size().sort_values(ascending=False)
# Out:
# 설치장소
# 경상남도 창원시 의창구 팔용동182번지           3
# 경상남도 창원시 성산구 상남로216번길           3
# 경상남도 창원시 성산구 창이대로574번길          3
# 경상남도 창원시 성산구 창이대로586번길          3
# 경상남도 창원시 성산구 신월로17번길 39         3
#                                ..
# 경상남도 창원시 마산합포구 진동면 문화마당길 193    1
# 경상남도 창원시 마산합포구 진동면 교동1길 7       1
# 경상남도 창원시 마산합포구 중앙북7길 2          1
# 경상남도 창원시 마산합포구 중앙북5길 25         1
# 창원시 성산구 외동 853-20               1
# Length: 1245, dtype: int64

# %%
# now i will plot the count of each location
import matplotlib.pyplot as plt

df.groupby('설치장소').size().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='설치장소'>
# /Users/min/miniforge3/envs/gn-project/lib/python3.10/site-packages/IPython/core/events.py:82: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from current font.
#   func(*args, **kwargs)
# /Users/min/miniforge3/envs/gn-project/lib/python3.10/site-packages/IPython/core/events.py:82: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   func(*args, **kwargs)
# /Users/min/miniforge3/envs/gn-project/lib/python3.10/site-packages/IPython/core/events.py:82: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   func(*args, **kwargs)
# /Users/min/miniforge3/envs/gn-project/lib/python3.10/site-packages/IPython/core/events.py:82: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   func(*args, **kwargs)
# ...
